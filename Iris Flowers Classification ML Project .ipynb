# %% [markdown]
# ### Name : Raman Kumar
#
# ### LetsGrow More Virtual Internship Prpgram Task 1

# %% [markdown]
# ###  Iris Flowers Classification ML Project :

# %% [markdown]
# #### Load Libraries

# %%
#Load Important Libraries

import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# #### Set Working Directory

# %%
os.chdir('C:\Internships & Projects\Lets Grow More Internship\Intermediate Level\Project 2')

# %% [markdown]
# #### Load The data

# %%
data = pd.read_csv("Iris.csv")
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #### Descriptive Statistics

# %%
data.shape
# Out:
# (150, 6)

# %%
#drop the ID column

data = data.drop("Id", axis=1)

# %%
data.describe().style.background_gradient(cmap = 'copper')
# Out:
# <style  type="text/css" >
# #T_4df68_row0_col0,#T_4df68_row0_col1,#T_4df68_row0_col2,#T_4df68_row0_col3{
#             background-color:  #ffc77f;
#             color:  #000000;
#         }#T_4df68_row1_col0,#T_4df68_row5_col0{
#             background-color:  #0a0604;
#             color:  #f1f1f1;
#         }#T_4df68_row1_col1,#T_4df68_row1_col2,#T_4df68_row4_col1,#T_4df68_row5_col1,#T_4df68_row6_col1,#T_4df68_row7_col3{
#             background-color:  #050302;
#             color:  #f1f1f1;
#         }#T_4df68_row1_col3,#T_4df68_row2_col2,#T_4df68_row2_col3,#T_4df68_row4_col2{
#             background-color:  #010100;
#             color:  #f1f1f1;
#         }#T_4df68_row2_col0,#T_4df68_row2_col1,#T_4df68_row3_col2,#T_4df68_row3_col3,#T_4df68_row4_col3{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_4df68_row3_col0,#T_4df68_row5_col2{
#             background-color:  #060402;
#             color:  #f1f1f1;
#         }#T_4df68_row3_col1,#T_4df68_row5_col3,#T_4df68_row6_col3{
#             background-color:  #020201;
#             color:  #f1f1f1;
#         }#T_4df68_row4_col0,#T_4df68_row6_col2{
#             background-color:  #090503;
#             color:  #f1f1f1;
#         }#T_4df68_row6_col0{
#             background-color:  #0b0704;
#             color:  #f1f1f1;
#         }#T_4df68_row7_col0{
#             background-color:  #0f0906;
#             color:  #f1f1f1;
#         }#T_4df68_row7_col1{
#             background-color:  #070503;
#             color:  #f1f1f1;
#         }#T_4df68_row7_col2{
#             background-color:  #0c0805;
#             color:  #f1f1f1;
#         }</style><table id="T_4df68_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SepalLengthCm</th>        <th class="col_heading level0 col1" >SepalWidthCm</th>        <th class="col_heading level0 col2" >PetalLengthCm</th>        <th class="col_heading level0 col3" >PetalWidthCm</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4df68_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_4df68_row0_col0" class="data row0 col0" >150.000000</td>
#                         <td id="T_4df68_row0_col1" class="data row0 col1" >150.000000</td>
#                         <td id="T_4df68_row0_col2" class="data row0 col2" >150.000000</td>
#                         <td id="T_4df68_row0_col3" class="data row0 col3" >150.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4df68_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_4df68_row1_col0" class="data row1 col0" >5.843333</td>
#                         <td id="T_4df68_row1_col1" class="data row1 col1" >3.054000</td>
#                         <td id="T_4df68_row1_col2" class="data row1 col2" >3.758667</td>
#                         <td id="T_4df68_row1_col3" class="data row1 col3" >1.198667</td>
#             </tr>
#             <tr>
#                         <th id="T_4df68_level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_4df68_row2_col0" class="data row2 col0" >0.828066</td>
#                         <td id="T_4df68_row2_col1" class="data row2 col1" >0.433594</td>
#                         <td id="T_4df68_row2_col2" class="data row2 col2" >1.764420</td>
#                         <td id="T_4df68_row2_col3" class="data row2 col3" >0.763161</td>
#             </tr>
#             <tr>
#                         <th id="T_4df68_level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_4df68_row3_col0" class="data row3 col0" >4.300000</td>
#                         <td id="T_4df68_row3_col1" class="data row3 col1" >2.000000</td>
#                         <td id="T_4df68_row3_col2" class="data row3 col2" >1.000000</td>
#                         <td id="T_4df68_row3_col3" class="data row3 col3" >0.100000</td>
#             </tr>
#             <tr>
#                         <th id="T_4df68_level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_4df68_row4_col0" class="data row4 col0" >5.100000</td>
#                         <td id="T_4df68_row4_col1" class="data row4 col1" >2.800000</td>
#                         <td id="T_4df68_row4_col2" class="data row4 col2" >1.600000</td>
#                         <td id="T_4df68_row4_col3" class="data row4 col3" >0.300000</td>
#             </tr>
#             <tr>
#                         <th id="T_4df68_level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_4df68_row5_col0" class="data row5 col0" >5.800000</td>
#                         <td id="T_4df68_row5_col1" class="data row5 col1" >3.000000</td>
#                         <td id="T_4df68_row5_col2" class="data row5 col2" >4.350000</td>
#                         <td id="T_4df68_row5_col3" class="data row5 col3" >1.300000</td>
#             </tr>
#             <tr>
#                         <th id="T_4df68_level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_4df68_row6_col0" class="data row6 col0" >6.400000</td>
#                         <td id="T_4df68_row6_col1" class="data row6 col1" >3.300000</td>
#                         <td id="T_4df68_row6_col2" class="data row6 col2" >5.100000</td>
#                         <td id="T_4df68_row6_col3" class="data row6 col3" >1.800000</td>
#             </tr>
#             <tr>
#                         <th id="T_4df68_level0_row7" class="row_heading level0 row7" >max</th>
#                         <td id="T_4df68_row7_col0" class="data row7 col0" >7.900000</td>
#                         <td id="T_4df68_row7_col1" class="data row7 col1" >4.400000</td>
#                         <td id="T_4df68_row7_col2" class="data row7 col2" >6.900000</td>
#                         <td id="T_4df68_row7_col3" class="data row7 col3" >2.500000</td>
#             </tr>
#     </tbody></table>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# #### Missing Value Analysis

# %%
missing_val = data.isna().sum()
missing_val
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# No Missing Value

# %% [markdown]
# #### EDA

# %%
# target Class Count
sns.countplot(y=data.Species ,data=data)
plt.xlabel("Count of each Target class")
plt.ylabel("Target classes")
plt.show()

# %%
#Distribution of length & Width
df=data.drop(['Species'], axis=1)
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in df.items():
    sns.distplot(v, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
#Sepal Length VS Sepal Width
fig = data[data.Species=='Iris-setosa'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='orange', label='Setosa')
data[data.Species=='Iris-versicolor'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='blue', label='versicolor',ax=fig)
data[data.Species=='Iris-virginica'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='green', label='virginica', ax=fig)
fig.set_xlabel("Sepal Length")
fig.set_ylabel("Sepal Width")
fig.set_title("Sepal Length VS Sepal Width")
plt.show()

# %%
#Petal Length VS Petal Width
fig = data[data.Species=='Iris-setosa'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='orange', label='Setosa')
data[data.Species=='Iris-versicolor'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='blue', label='versicolor',ax=fig)
data[data.Species=='Iris-virginica'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='green', label='virginica', ax=fig)
fig.set_xlabel("Petal Length")
fig.set_ylabel("Petal Width")
fig.set_title(" Petal Length VS Petal Width")
plt.show()

# %% [markdown]
# we can see that the Petal Features are giving a better cluster division compared to the Sepal features.

# %% [markdown]
# #### Correlation Analysis

# %%
data.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
plt.figure(figsize=(10,10))
p=sns.heatmap(data.corr(), annot=True,cmap='RdYlGn')

# %% [markdown]
# ### Machine Learning

# %% [markdown]
# #### Label Encoding the target class as ML deals only with Numerical features

# %%
# Import label encoder
from sklearn import preprocessing
 
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
 
# Encode labels in column 'species'.
data['Species']= label_encoder.fit_transform(data['Species'])
 
data['Species'].unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# ### Train Test Split

# %%
# Dividing data into Train and Test
from sklearn.model_selection import train_test_split , cross_val_score
X = data.drop('Species', axis=1)
y = data['Species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %% [markdown]
# #### Scaling The Data

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# selecting the classifier
log_reg= LogisticRegression()


log_reg.fit(X_train, y_train)

# checking model performance
y_pred= log_reg.predict(X_test)

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

cm= confusion_matrix(y_test, y_pred)
print(cm)
sns.heatmap(cm, annot=True)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[18  0  0]
#  [ 0 10  0]
#  [ 0  1 16]]
# 0.9777777777777777
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       0.91      1.00      0.95        10
#            2       1.00      0.94      0.97        17
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.97        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# ### RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
# checking model performance
y_predicted = rfc.predict(X_test)

# %% [markdown]
# ### Model Evaluation

# %%
cm= confusion_matrix(y_test, y_predicted)
print(cm)
sns.heatmap(cm, annot=True)
print(accuracy_score(y_test, y_predicted))
print(classification_report(y_test, y_predicted))
# Out:
# [[18  0  0]
#  [ 0 10  0]
#  [ 0  2 15]]
# 0.9555555555555556
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       0.83      1.00      0.91        10
#            2       1.00      0.88      0.94        17
#
#     accuracy                           0.96        45
#    macro avg       0.94      0.96      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %% [markdown]
# ### K – Nearest Neighbor (KNN) Classification

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# checking model performance
pred_y= classifier.predict(X_test)

# %% [markdown]
# ### Model Evaluation

# %%
cm= confusion_matrix(y_test, pred_y)
print(cm)
sns.heatmap(cm, annot=True)
print(accuracy_score(y_test, pred_y))
print(classification_report(y_test, pred_y))
# Out:
# [[18  0  0]
#  [ 0  9  1]
#  [ 0  2 15]]
# 0.9333333333333333
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       0.82      0.90      0.86        10
#            2       0.94      0.88      0.91        17
#
#     accuracy                           0.93        45
#    macro avg       0.92      0.93      0.92        45
# weighted avg       0.94      0.93      0.93        45

# %% [markdown]
# ##### Thank You
